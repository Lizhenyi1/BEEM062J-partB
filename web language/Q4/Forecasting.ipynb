# %%
pip install cryptocompare
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\lee journey\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install quandl
# Out:
# ...
#
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\lee journey\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import json
import requests
import datetime

# %%
import pandas as pd
import numpy as np
import cryptocompare
import quandl

# %% [markdown]
# ### use dollar and bitcoin prices

# %%
yt = cryptocompare.get_historical_price_day('BTC', currency='USD')
yt = pd.DataFrame(yt)
yt.head()
# Out:
#          time     high      low     open  volumefrom      volumeto    close  \
# 0  1535241600  6793.17  6588.48  6749.71    39682.91  2.658206e+08  6720.60
# 1  1535328000  6944.21  6674.84  6720.60    59984.28  4.057693e+08  6915.73
# 2  1535414400  7136.71  6877.20  6915.92    69448.01  4.877896e+08  7091.38
# 3  1535500800  7137.47  6944.76  7091.38    50361.95  3.561390e+08  7052.00
# 4  1535587200  7072.64  6818.69  7051.61    61266.88  4.254757e+08  6998.76
#
#   conversionType conversionSymbol
# 0         direct
# 1         direct
# 2         direct
# 3         direct
# 4         direct

# %% [markdown]
# ### fetch prices from Quandl API that might affecting the price of bitcoin.

# %%
quandl.ApiConfig.api_key = "gm-G9bEg2g2G2tC7NvWU"

# %%
datax1=quandl.get("LBMA/GOLD")
datax1.head()
# Out:
#             USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# Date
# 1968-01-02     35.18       NaN    14.641       NaN        NaN        NaN
# 1968-01-03     35.16       NaN    14.617       NaN        NaN        NaN
# 1968-01-04     35.14       NaN    14.603       NaN        NaN        NaN
# 1968-01-05     35.14       NaN    14.597       NaN        NaN        NaN
# 1968-01-08     35.14       NaN    14.586       NaN        NaN        NaN

# %%
datax2=quandl.get("EIA/PET_RWTC_D")
datax2.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
datax3=quandl.get("OPEC/ORB")
datax3.head()
# Out:
#             Value
# Date
# 2003-01-02  30.05
# 2003-01-03  30.83
# 2003-01-06  30.71
# 2003-01-07  29.72
# 2003-01-08  28.86

# %%
datax4=quandl.get("BATS/BATS_TSLA")
datax4.head()
# Out:
#             Short Volume  Total Volume
# Date
# 2010-06-29      519232.0     1086984.0
# 2010-06-30      309457.0      629033.0
# 2010-07-01      112425.0      299553.0
# 2010-07-02      153978.0      225273.0
# 2010-07-06      179262.0      308389.0

# %%
datax5=quandl.get("BP/GAS_PROD_D_RUS")
datax5.head()
# Out:
#             Value
# Date
# 1970-12-31    0.0
# 1971-12-31    0.0
# 1972-12-31    0.0
# 1973-12-31    0.0
# 1974-12-31    0.0

# %%
datax6=quandl.get("ECB/MFI_M_GB_103_C_4")
datax6.head()
# Out:
#             Pure number
# Date
# 1999-01-31          0.0
# 1999-02-28          0.0
# 1999-03-31          0.0
# 1999-04-30          0.0
# 1999-05-31          0.0

# %%
datax8=quandl.get("BCB/229")
datax8.head()
# Out:
#             Value
# Date
# 1994-07-31   6.08
# 1994-08-31   5.46
# 1994-09-30   1.51
# 1994-10-31   1.86
# 1994-11-30   3.27

# %%
datax7=quandl.get("BSE/BOM531724")
datax7.head()
# Out:
#              Open   High    Low  Close    WAP  No. of Shares  No. of Trades  \
# Date
# 1996-06-11  20.00  20.00  20.00  20.00  20.00          100.0            1.0
# 1996-06-12  16.00  16.00  14.25  14.25  14.53          900.0            5.0
# 1996-06-21  12.00  12.00  12.00  12.00  12.00          100.0            1.0
# 1996-08-23  11.25  11.25  11.25  11.25  11.25          200.0            1.0
# 1996-09-06  10.00  10.00  10.00  10.00  10.00          200.0            1.0
#
#             Total Turnover  Deliverable Quantity  % Deli. Qty to Traded Qty  \
# Date
# 1996-06-11          2000.0                   NaN                        NaN
# 1996-06-12         13075.0                   NaN                        NaN
# 1996-06-21          1200.0                   NaN                        NaN
# 1996-08-23          2250.0                   NaN                        NaN
# 1996-09-06          2000.0                   NaN                        NaN
#
#             Spread H-L  Spread C-O
# ...

# %%
datax7=quandl.get("BCB/228")
datax7.head()
# Out:
#                Value
# Date
# 1994-05-30  1.017519
# 1994-05-31  1.018404
# 1994-06-01  1.018331
# 1994-06-02  1.000000
# 1994-06-03  1.018395

# %%
datax9=quandl.get("BCB/227")
datax9.head()
# Out:
#                Value
# Date
# 1993-07-01  1.260157
# 1993-07-02  1.254594
# 1993-07-03  1.249767
# 1993-07-04  1.244322
# 1993-07-05  1.238585

# %%
datax10=quandl.get("BSE/BOM531724")
datax10.head()

# %%
yt.time= yt.time.apply(lambda d: datetime.datetime.fromtimestamp(int(d)).strftime('%Y-%m-%d'))

# %%
yt['time'] = pd.to_datetime(yt['time'], errors='coerce')

# %%
yt = yt[yt.time.dt.weekday <5]

# %%
yt =yt[['time','close']]

# %%
yt=yt.set_index('time')

# %%
yt.columns = ['Value']
yt.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9932/2912459562.py in <module>
# ----> 1 yt.columns = ['Value']
#       2 yt.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
# ...
